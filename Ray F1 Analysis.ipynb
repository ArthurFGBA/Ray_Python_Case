# %%
#instalação de pacotes necessários para o código
# !pip install --upgrade pip
# !pip install google-auth google-auth-oauthlib google-auth-httplib2 google-api-python-client
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
#fornecendo variaveis base para o código
from googleapiclient.discovery import build
import pandas as pd

#chave de API
api_key = 'AIzaSyAoYcDz9aL29wbeCkGiXJ9vuMdq-_XdGHU'
youtube_api_service_name = 'youtube'
youtube_api_version = 'v3'

youtube = build(youtube_api_service_name, youtube_api_version, developerKey=api_key)

channel_id= 'UCB_qr75-ydFVKSF9Dmo6izg'

# %% [markdown]
# # Dados do Canal oficial da Formula 1

# %%
#retendo informações do canal 
def get_channel_stats(youtube, channel_id):
    
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=channel_id)
    response = request.execute()
    
    data = dict(Channel_name = response['items'][0]['snippet']['title'],
               Subscribers = response['items'][0]['statistics']['subscriberCount'],
                Views = response['items'][0]['statistics']['viewCount'],
                Total_videos = response['items'][0]['statistics']['videoCount']
               )
    return data

# %%
#testando função
get_channel_stats(youtube, channel_id)
# Out:
# {'Channel_name': 'FORMULA 1',
#  'Subscribers': '11400000',
#  'Views': '7423002051',
#  'Total_videos': '8157'}

# %%
#demonstração de dados do canal
f1 = get_channel_stats(youtube, channel_id)
df_canal = pd.DataFrame([f1])
df_canal
# Out:
#   Channel_name Subscribers       Views Total_videos
# 0    FORMULA 1    11400000  7423002051         8157

# %% [markdown]
# # Dados Playlist Highlights Corridas 2024

# %%
#fornecendo variaveis 
playlistid = 'PLfoNZDHitwjUv0pjTwlV1vzaE0r7UDVDR'

# %%
#retirada de ids dos videos a partir de id da playlist
def get_playlist_ids(youtube, playlistid):
    all_ids=[]
    request = youtube.playlistItems().list(
        part='snippet,contentDetails',
        playlistId = playlistid,
        maxResults=50
        )
    response = request.execute()

    for i in range(len(response['items'])):
        id = response['items'][i]['contentDetails']['videoId']
        all_ids.append(id)
    return all_ids

# %%
#Armazenando ids dos videos da playlist
videos_ids = get_playlist_ids(youtube, playlistid)
print(videos_ids)
# Out:
# ['Qa0nj2CcaSM', 'NGSPg5ns2-0', 'sNd1-1GjMDY', 'gbxJT-yBdcs', '3efwPrjwNVY', 'kLCytMTycxI', 'slCskHrI_Vg', '7ynDOY1PR74', 'sTmpbEYUba0', 'cFM_6zb35rI', 'pQaG0ay957M', 'YJ0NYHONwts', 'yPvoKz6tyJs', 'b0yb1zH2m7c', 'ojUQLuSqV4s', 'dLw1ao4-Akk', 'aeCI0ObFY8M', 'wya4iAJLlzs', '9wiQqcKUahc', 'hh4prBn66Dc', 'Z3-IulIyBtU', '9z8sEadieXA', 'OJ56MAGFPGM', '9Y5wMpKXNK4']

# %%
#função para retirada de nome e quantidade de views a partir da lista de ids
def get_playlist_stats(youtube,videos_ids):
    all_data = []
    request = youtube.videos().list(
        part="snippet,statistics",
        id=videos_ids)
    response = request.execute()
    
    for i in range(len(response['items'])):
        data = dict(Video_name = response['items'][i]['snippet']['title'],
                    Views = response['items'][i]['statistics']['viewCount']
        )
        all_data.append(data)
    return all_data

# %%
#teste da função
get_playlist_stats(youtube,videos_ids)
# Out:
# [{'Video_name': 'Race Highlights | 2024 Abu Dhabi Grand Prix',
#   'Views': '5197738'},
#  {'Video_name': 'Race Highlights | 2024 Qatar Grand Prix', 'Views': '5091652'},
#  {'Video_name': 'Race Highlights | 2024 Las Vegas Grand Prix',
#   'Views': '6464541'},
#  {'Video_name': 'Race Highlights | 2024 Sao Paulo Grand Prix',
#   'Views': '8002995'},
#  {'Video_name': 'Race Highlights | 2024 Mexico City Grand Prix',
#   'Views': '6441109'},
#  {'Video_name': 'Race Highlights | 2024 United States Grand Prix',
#   'Views': '5909361'},
#  {'Video_name': 'Race Highlights | 2024 Singapore Grand Prix',
#   'Views': '5656854'},
#  {'Video_name': 'Race Highlights | 2024 Azerbaijan Grand Prix',
#   'Views': '6893726'},
#  {'Video_name': 'Race Highlights | 2024 Italian Grand Prix',
#   'Views': '6680366'},
#  {'Video_name': 'Race Highlights | 2024 Dutch Grand Prix', 'Views': '5731027'},
#  {'Video_name': 'Race Highlights | 2024 Belgian Grand Prix',
#   'Views': '6814252'},
# ...

# %%
#criando dataframe a partir de dicionario com dados
playlist_data = get_playlist_stats(youtube,videos_ids)
df = pd.DataFrame(playlist_data)
df
# Out:
#                                           Video_name    Views
# 0        Race Highlights | 2024 Abu Dhabi Grand Prix  5197738
# 1            Race Highlights | 2024 Qatar Grand Prix  5091652
# 2        Race Highlights | 2024 Las Vegas Grand Prix  6464541
# 3        Race Highlights | 2024 Sao Paulo Grand Prix  8002995
# 4      Race Highlights | 2024 Mexico City Grand Prix  6441109
# 5    Race Highlights | 2024 United States Grand Prix  5909361
# 6        Race Highlights | 2024 Singapore Grand Prix  5656854
# 7       Race Highlights | 2024 Azerbaijan Grand Prix  6893726
# 8          Race Highlights | 2024 Italian Grand Prix  6680366
# 9            Race Highlights | 2024 Dutch Grand Prix  5731027
# 10         Race Highlights | 2024 Belgian Grand Prix  6814252
# 11       Race Highlights | 2024 Hungarian Grand Prix  8886105
# 12         Race Highlights | 2024 British Grand Prix  7501804
# 13        Race Highlights | 2024 Austrian Grand Prix  6262501
# ...

# %%
#ordenando os videos pelo numero de visualizações
df = df.sort_values(by=['Views'], ascending=[False])
df
# Out:
#                                           Video_name    Views
# 21      Race Highlights | 2024 Australian Grand Prix  9664768
# 16          Race Highlights | 2024 Monaco Grand Prix  9020784
# 11       Race Highlights | 2024 Hungarian Grand Prix  8886105
# 3        Race Highlights | 2024 Sao Paulo Grand Prix  8002995
# 18           Race Highlights | 2024 Miami Grand Prix  7608189
# 12         Race Highlights | 2024 British Grand Prix  7501804
# 20        Race Highlights | 2024 Japanese Grand Prix  7177407
# 7       Race Highlights | 2024 Azerbaijan Grand Prix  6893726
# 10         Race Highlights | 2024 Belgian Grand Prix  6814252
# 19         Race Highlights | 2024 Chinese Grand Prix  6710839
# 8          Race Highlights | 2024 Italian Grand Prix  6680366
# 22   Race Highlights | 2024 Saudi Arabian Grand Prix  6651943
# 23         Race Highlights | 2024 Bahrain Grand Prix  6518635
# 2        Race Highlights | 2024 Las Vegas Grand Prix  6464541
# ...
